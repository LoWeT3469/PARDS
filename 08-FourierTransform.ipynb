# %% [markdown]
# ### Fourier transform:
#
# - [Python code](https://realpython.com/python-scipy-fft/)
#
# - [scipy.fft](https://docs.scipy.org/doc/scipy/tutorial/fft.html#d-discrete-fourier-transforms)

# %%
# 58_CDGR_39_1st (1) Demo / 58_AVEAA_4_1st (1) Demo

import pandas as pd

# # Define the file path (CDGR ventilator)
# file_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_1st/a-58_CDGR_39_1st_OSI/a-58_CDGR_39_1st_tw/a_58_CDGR_39_1st (1).csv"

# # Define the file path (AVEAA ventilator)
# file_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_1st/a-58_AVEAA_4_1st_OSI/a-58_AVEAA_4_1st_tw/a_58_AVEAA_4_1st (1).csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Remove rows with at least one empty value across all columns
df = df.dropna()

# Convert 'Time' column to datetime format
df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

# # Display the DataFrame
# print(df.info())
# print(df.head())
# print(df.tail())

# %%
### CDGR demo
# # 1st minute from the 1st tumbling window.
# start_time = '2023-10-04 17:31:21'
# end_time = '2023-10-04 17:32:21'

# # 2nd minute from the 1st tumbling window.
# start_time = '2023-10-04 17:32:21'
# end_time = '2023-10-04 17:33:21'

# # 3rd minute from the 1st tumbling window.
# start_time = '2023-10-04 17:33:21'
# end_time = '2023-10-04 17:34:21'

# # 4th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:34:21'
# end_time = '2023-10-04 17:35:21'

# # 5th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:35:21'
# end_time = '2023-10-04 17:36:21'

# # 6th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:36:21'
# end_time = '2023-10-04 17:37:21'

# # 7th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:37:21'
# end_time = '2023-10-04 17:38:21'

# # 8th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:38:21'
# end_time = '2023-10-04 17:39:21'

# # 9th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:39:21'
# end_time = '2023-10-04 17:40:21'

# # 10th minute from the 1st tumbling window.
# start_time = '2023-10-04 17:40:21'
# end_time = '2023-10-04 17:41:21'

# # 1st minute from the 2nd tumbling window.
# start_time = '2023-10-04 17:41:00'
# end_time = '2023-10-04 17:42:00'

# # 1st minute from the 3rd tumbling window.
# start_time = '2023-10-04 17:51:00'
# end_time = '2023-10-04 17:52:00'

# # 1st minute from the 4th tumbling window.
# start_time = '2023-10-04 18:01:00'
# end_time = '2023-10-04 18:02:00'

# # 1st minute from the 5th tumbling window.
# start_time = '2023-10-04 18:11:00'
# end_time = '2023-10-04 18:12:00'

# # 1st minute from the 6th tumbling window.
# start_time = '2023-10-04 18:21:00'
# end_time = '2023-10-04 18:22:00'

# %%
### AVEAA demo
# # 1st minute from the 1st tumbling window.
# start_time = '2023-12-18 20:14:35'
# end_time = '2023-12-18 20:15:35'

# # 2nd minute from the 1st tumbling window.
# start_time = '2023-12-18 20:15:35'
# end_time = '2023-12-18 20:16:35'

# # 3rd minute from the 1st tumbling window.
# start_time = '2023-12-18 20:16:35'
# end_time = '2023-12-18 20:17:35'

# # 4th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:17:35'
# end_time = '2023-12-18 20:18:35'

# # 5th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:18:35'
# end_time = '2023-12-18 20:19:35'

# # 6th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:19:35'
# end_time = '2023-12-18 20:20:35'

# # 7th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:20:35'
# end_time = '2023-12-18 20:21:35'

# # 8th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:21:35'
# end_time = '2023-12-18 20:22:35'

# # 9th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:22:35'
# end_time = '2023-12-18 20:23:35'

# # 10th minute from the 1st tumbling window.
# start_time = '2023-12-18 20:23:35'
# end_time = '2023-12-18 20:24:35'

# # 1st minute from the 2nd tumbling window.
# start_time = '2023-12-18 20:24:00'
# end_time = '2023-12-18 20:25:00'

# # 1st minute from the 3rd tumbling window.
# start_time = '2023-12-18 20:34:00'
# end_time = '2023-12-18 20:35:00'

# # 1st minute from the 4th tumbling window.
# start_time = '2023-12-18 20:44:00'
# end_time = '2023-12-18 20:45:00'

# # 1st minute from the 5th tumbling window.
# start_time = '2023-12-18 20:54:00'
# end_time = '2023-12-18 20:55:00'

# # 1st minute from the 6th tumbling window.
# start_time = '2023-12-18 21:04:00'
# end_time = '2023-12-18 21:05:00'

# %%
# Subset the data based on the time range
subset_df = df[(df['Time'] >= start_time) & (df['Time'] <= end_time)]

# Display the subset DataFrame
print(subset_df.info())
# print(subset_df.head())
# print(subset_df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5859 entries, 59127 to 64985
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Relative Time (sec)  5859 non-null   float64
#  1   Time                 5859 non-null   datetime64[ns]
#  2   CDGR - FiO₂          5859 non-null   int64
#  3   CDGR - Paw           5859 non-null   int64
#  4   CDGR - eVT           5859 non-null   float64
#  5   CDGR - Flow          5859 non-null   float64
#  6   CDGR - iPress Wave   5859 non-null   float64
#  7   GE - SpO2 1          5859 non-null   float64
#  8   OSI                  5859 non-null   float64
#  9   Tumbling_window      5859 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 503.5 KB
# None

# %%
# # CDGR pressure time domain demo
# import matplotlib.pyplot as plt

# # Plot the original waveform
# plt.figure(figsize=(10, 5))
# plt.plot(subset_df['CDGR - iPress Wave'])
# plt.xlabel('Time')
# plt.ylabel('CDGR - iPress Wave')
# plt.title('Original CDGR - iPress Waveform')
# plt.grid(True)
# plt.show()

# # AVEAA PIP time domain demo
# import matplotlib.pyplot as plt

# # Plot the original waveform
# plt.figure(figsize=(10, 5))
# plt.plot(subset_df['AVEA - PIP'])
# plt.xlabel('Time')
# plt.ylabel('AVEA - PIP')
# plt.title('Original AVEA - PIP')
# plt.grid(True)
# plt.show()

# %%
# CDGR / AVEAA frequency domain demo (code from https://realpython.com/python-scipy-fft/)

from scipy.fft import rfft, rfftfreq
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt

# Perform Fourier transform
x = subset_df["CDGR - iPress Wave"].values  # Input signal
# x = subset_df["AVEA - PIP"].values  # Input signal
fs = 200  # Sampling frequency (CDGR pressure)
# fs = 0.2  # Sampling frequency

# Number of samples in x
n = len(x)

# Compute the Fourier transform
yf = rfft(x)   # The amplitude
yf = 20 * np.log10(yf)   # Convert amplitude to gain in decibels (dB)
xf = rfftfreq(n, 1 / fs)

# Define the prominence values to test
prominences = [5, 10, 15, 20, 25]

for prominence in prominences:
    # Find peaks in the frequency spectrum
    peaks, _ = find_peaks(np.abs(yf), prominence=prominence)
    
    # Calculate the derivative of the gain curve
    dyf = np.gradient(yf, xf)

    # Find the peak corresponding to the "elbow" area
    elbow_peak_idx = np.argmax(dyf[peaks])

    # Find the minimum peak
    min_peak_idx = np.argmin(np.abs(yf[peaks]))

    # Plot the frequency content
    plt.figure(figsize=(10, 5))
    plt.plot(xf, np.abs(yf))
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Gain (dB)')
    plt.title(f'Frequency Content (Prominence={prominence})')
    plt.grid(True)
    
    # Annotate peaks in the plot
    for peak in peaks:
        plt.plot(xf[peak], np.abs(yf[peak]), 'ro', markersize=2)  # Plot a red dot at the peak position

    # Annotate maximum peak
    max_peak_idx = np.argmax(np.abs(yf[peaks]))
    plt.annotate(f'Max Peak: {xf[peaks[max_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[max_peak_idx]], np.abs(yf[peaks[max_peak_idx]])), 
                 xytext=(10, 20),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='red',
                 fontsize=16)

    # Annotate minimum peak at the "elbow" area
    plt.annotate(f'Elbow Peak: {xf[peaks[elbow_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[elbow_peak_idx]], np.abs(yf[peaks[elbow_peak_idx]])), 
                 xytext=(10, 60),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='blue',
                 fontsize=16)

    # Annotate minimum peak
    plt.annotate(f'Min Peak: {xf[peaks[min_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[min_peak_idx]], np.abs(yf[peaks[min_peak_idx]])), 
                 xytext=(10, 100),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='red',
                 fontsize=16)

    plt.show()

# %%
# # AVEAA PEEP time domain demo
# import matplotlib.pyplot as plt

# # Plot the original waveform
# plt.figure(figsize=(10, 5))
# plt.plot(subset_df['AVEA - PEEP'])
# plt.xlabel('Time')
# plt.ylabel('AVEA - PEEP')
# plt.title('Original AVEA - PEEP')
# plt.grid(True)
# plt.show()

# %%
# # CDGR / AVEAA frequency domain demo (code from https://realpython.com/python-scipy-fft/)

# from scipy.fft import rfft, rfftfreq
# from scipy.signal import find_peaks
# import numpy as np
# import matplotlib.pyplot as plt

# # Perform Fourier transform 
# x = subset_df["AVEA - PEEP"].values  # Input signal
# fs = 0.2  # Sampling frequency

# # Number of samples in x
# n = len(x)

# # Compute the Fourier transform
# yf = rfft(x)   # The amplitude
# yf = 20 * np.log10(yf)   # Convert amplitude to gain in decibels (dB)
# xf = rfftfreq(n, 1 / fs)

# # Define the prominence values to test
# prominences = [5, 10, 15, 20, 25]

# for prominence in prominences:
#     # Find peaks in the frequency spectrum
#     peaks, _ = find_peaks(np.abs(yf), prominence=prominence)
    
#     # Calculate the derivative of the gain curve
#     dyf = np.gradient(yf, xf)

#     # Find the peak corresponding to the "elbow" area
#     elbow_peak_idx = np.argmax(dyf[peaks])

#     # Find the minimum peak
#     min_peak_idx = np.argmin(np.abs(yf[peaks]))

#     # Plot the frequency content
#     plt.figure(figsize=(10, 5))
#     plt.plot(xf, np.abs(yf))
#     plt.xlabel('Frequency [Hz]')
#     plt.ylabel('Gain (dB)')
#     plt.title(f'Frequency Content (Prominence={prominence})')
#     plt.grid(True)
    
#     # Annotate peaks in the plot
#     for peak in peaks:
#         plt.plot(xf[peak], np.abs(yf[peak]), 'ro', markersize=2)  # Plot a red dot at the peak position

#     # Annotate maximum peak
#     max_peak_idx = np.argmax(np.abs(yf[peaks]))
#     plt.annotate(f'Max Peak: {xf[peaks[max_peak_idx]]:.2f} Hz', 
#                  xy=(xf[peaks[max_peak_idx]], np.abs(yf[peaks[max_peak_idx]])), 
#                  xytext=(10, 20),
#                  textcoords='offset points',
#                  arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
#                  color='red',
#                  fontsize=16)

#     # Annotate minimum peak at the "elbow" area
#     plt.annotate(f'Elbow Peak: {xf[peaks[elbow_peak_idx]]:.2f} Hz', 
#                  xy=(xf[peaks[elbow_peak_idx]], np.abs(yf[peaks[elbow_peak_idx]])), 
#                  xytext=(10, 60),
#                  textcoords='offset points',
#                  arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
#                  color='blue',
#                  fontsize=16)

#     # Annotate minimum peak
#     plt.annotate(f'Min Peak: {xf[peaks[min_peak_idx]]:.2f} Hz', 
#                  xy=(xf[peaks[min_peak_idx]], np.abs(yf[peaks[min_peak_idx]])), 
#                  xytext=(10, 100),
#                  textcoords='offset points',
#                  arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
#                  color='red',
#                  fontsize=16)

#     plt.show()

# %%
# # CDGR flow time domain demo
# import matplotlib.pyplot as plt

# # Plot the original waveform
# plt.figure(figsize=(10, 5))
# plt.plot(subset_df['CDGR - Flow'])
# plt.xlabel('Time')
# plt.ylabel('CDGR - Flow')
# plt.title('Original CDGR - Flow Waveform')
# plt.grid(True)
# plt.show()

# # AVEAA flow time domain demo
# import matplotlib.pyplot as plt

# # Plot the original waveform
# plt.figure(figsize=(10, 5))
# plt.plot(subset_df['AVEA - Air Flow Wave'])
# plt.xlabel('Time')
# plt.ylabel('AVEA - Air Flow Wave')
# plt.title('Original AVEA - Air Flow Wave')
# plt.grid(True)
# plt.show()

# %%
# CDGR / AVEAA frequency domain demo (code from https://realpython.com/python-scipy-fft/)

from scipy.fft import rfft, rfftfreq
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt

# Perform Fourier transform 
# x = subset_df["CDGR - Flow"].values  # Input signal
x = subset_df["AVEA - Air Flow Wave"].values  # Input signal
# fs = 200  # Sampling frequency (CDGR flow)
fs = 100  # Sampling frequency

# Number of samples in x
n = len(x)

# Compute the Fourier transform
yf = rfft(x)   # The amplitude
yf = 20 * np.log10(yf)   # Convert amplitude to gain in decibels (dB)
xf = rfftfreq(n, 1 / fs)

# Define the prominence values to test
prominences = [5, 10, 15, 20, 25]

for prominence in prominences:
    # Find peaks in the frequency spectrum
    peaks, _ = find_peaks(np.abs(yf), prominence=prominence)
    
    # Calculate the derivative of the gain curve
    dyf = np.gradient(yf, xf)

    # Find the peak corresponding to the "elbow" area
    elbow_peak_idx = np.argmax(dyf[peaks])

    # Find the minimum peak
    min_peak_idx = np.argmin(np.abs(yf[peaks]))

    # Plot the frequency content
    plt.figure(figsize=(10, 5))
    plt.plot(xf, np.abs(yf))
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Gain (dB)')
    plt.title(f'Frequency Content (Prominence={prominence})')
    plt.grid(True)
    
    # Annotate peaks in the plot
    for peak in peaks:
        plt.plot(xf[peak], np.abs(yf[peak]), 'ro', markersize=2)  # Plot a red dot at the peak position

    # Annotate maximum peak
    max_peak_idx = np.argmax(np.abs(yf[peaks]))
    plt.annotate(f'Max Peak: {xf[peaks[max_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[max_peak_idx]], np.abs(yf[peaks[max_peak_idx]])), 
                 xytext=(10, 20),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='red',
                 fontsize=16)

    # Annotate minimum peak at the "elbow" area
    plt.annotate(f'Elbow Peak: {xf[peaks[elbow_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[elbow_peak_idx]], np.abs(yf[peaks[elbow_peak_idx]])), 
                 xytext=(10, 60),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='blue',
                 fontsize=16)

    # Annotate minimum peak
    plt.annotate(f'Min Peak: {xf[peaks[min_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[min_peak_idx]], np.abs(yf[peaks[min_peak_idx]])), 
                 xytext=(10, 100),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='red',
                 fontsize=16)

    plt.show()

# %%
# CDGR volume time domain demo
import matplotlib.pyplot as plt

# Plot the original waveform
plt.figure(figsize=(10, 5))
plt.plot(subset_df['CDGR - eVT'])
plt.xlabel('Time')
plt.ylabel('CDGR - eVT')
plt.title('Original CDGR - eVT Waveform')
plt.grid(True)
plt.show()

# # AVEAA volume time domain demo
# import matplotlib.pyplot as plt

# # Plot the original waveform
# plt.figure(figsize=(10, 5))
# plt.plot(subset_df['AVEA - eVT'])
# plt.xlabel('Time')
# plt.ylabel('AVEA - eVT')
# plt.title('Original AVEA - eVT')
# plt.grid(True)
# plt.show()

# %%
# CDGR / AVEAA frequency domain demo (code from https://realpython.com/python-scipy-fft/)

from scipy.fft import rfft, rfftfreq
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt

# Perform Fourier transform 
x = subset_df["CDGR - eVT"].values  # Input signal
# x = subset_df["AVEA - eVT"].values  # Input signal
fs = 0.5  # Sampling frequency (CDGR volume)
# fs = 0.2  # Sampling frequency

# Number of samples in x
n = len(x)

# Compute the Fourier transform
yf = rfft(x)   # The amplitude
yf = 20 * np.log10(yf)   # Convert amplitude to gain in decibels (dB)
xf = rfftfreq(n, 1 / fs)

# Define the prominence values to test
prominences = [5, 10, 15, 20, 25]

for prominence in prominences:
    # Find peaks in the frequency spectrum
    peaks, _ = find_peaks(np.abs(yf), prominence=prominence)
    
    # Calculate the derivative of the gain curve
    dyf = np.gradient(yf, xf)

    # Find the peak corresponding to the "elbow" area
    elbow_peak_idx = np.argmax(dyf[peaks])

    # Find the minimum peak
    min_peak_idx = np.argmin(np.abs(yf[peaks]))

    # Plot the frequency content
    plt.figure(figsize=(10, 5))
    plt.plot(xf, np.abs(yf))
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Gain (dB)')
    plt.title(f'Frequency Content (Prominence={prominence})')
    plt.grid(True)
    
    # Annotate peaks in the plot
    for peak in peaks:
        plt.plot(xf[peak], np.abs(yf[peak]), 'ro', markersize=2)  # Plot a red dot at the peak position

    # Annotate maximum peak
    max_peak_idx = np.argmax(np.abs(yf[peaks]))
    plt.annotate(f'Max Peak: {xf[peaks[max_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[max_peak_idx]], np.abs(yf[peaks[max_peak_idx]])), 
                 xytext=(10, 20),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='red',
                 fontsize=16)

    # Annotate minimum peak at the "elbow" area
    plt.annotate(f'Elbow Peak: {xf[peaks[elbow_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[elbow_peak_idx]], np.abs(yf[peaks[elbow_peak_idx]])), 
                 xytext=(10, 60),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='blue',
                 fontsize=16)

    # Annotate minimum peak
    plt.annotate(f'Min Peak: {xf[peaks[min_peak_idx]]:.2f} Hz', 
                 xy=(xf[peaks[min_peak_idx]], np.abs(yf[peaks[min_peak_idx]])), 
                 xytext=(10, 100),
                 textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
                 color='red',
                 fontsize=16)

    plt.show()
