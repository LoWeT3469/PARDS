# %% [markdown]
# Eliminate the first and the last five minutes data.
#
# - Reason: During the initial minutes, patients may be adapting to the situation (e.g., feeling uncomfortable), potentially introducing additional noise.
#
# - Butterworth Bandpass Filter (BBF) have transient effects at the beginning and end of the filtered signal.

# %%
## (Code for individual sample):

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_1st/a-58_CDGR_39_1st_OSI/a-58_CDGR_39_1st_FTandBBF/"
filename = "a_58_CDGR_39_1st (1).csv"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "a-58_CDGR_39_1st_No55")
os.makedirs(new_directory, exist_ok=True)

filepath = os.path.join(directory, filename)

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filepath)

# Convert 'Time' column to datetime format
df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

# Check if the 'Time' column exists
if 'Time' in df.columns:
    # Delete the first and last five minutes of data
    five_minutes = pd.Timedelta(minutes=5)
    min_time = df['Time'].min() + five_minutes
    max_time = df['Time'].max() - five_minutes
    df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

    # Save the modified DataFrame to a new CSV file in the new directory
    new_filepath = os.path.join(new_directory, filename)
    df.to_csv(new_filepath, index=False)

# %%
import matplotlib.pyplot as plt

# Plot both the real and imaginary parts of the inverted signal for the middle part
plt.figure(figsize=(10, 5))
plt.plot(df['CDGR - iPress Wave'])
plt.xlabel('Time')
plt.ylabel('Wave')
plt.title('Wave Which Eliminate the First and the Last Five Minutes')
plt.grid(True)
plt.show()

# %%
## 58_CDGR_39_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_1st/a-58_CDGR_39_1st_OSI/a-58_CDGR_39_1st_FTandBBF/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "a-58_CDGR_39_1st_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)

# %%
## 58_CDGR_39_12th cohort:
# Note: 'a_58_CDGR_39_12th (28).csv' is empty

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_12th/a-58_CDGR_39_12th_OSI/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "a-58_CDGR_39_12th_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        try:
            # Read the CSV file into a pandas DataFrame
            df = pd.read_csv(filepath)

            # Convert 'Time' column to datetime format
            df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

            # Check if the DataFrame is not empty
            if not df.empty:
                # Delete the first and last five minutes of data
                five_minutes = pd.Timedelta(minutes=5)
                min_time = df['Time'].min() + five_minutes
                max_time = df['Time'].max() - five_minutes
                df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

                # Save the modified DataFrame to a new CSV file in the new directory
                new_filepath = os.path.join(new_directory, filename)
                df.to_csv(new_filepath, index=False)
            else:
                print(f"Skipping: {filename} because the DataFrame is empty.")
        except pd.errors.EmptyDataError:
            print(f"Skipping: {filename} because the file is empty.")
# Out:
# Skipping: a_58_CDGR_39_12th (28).csv because the file is empty.

# %%
## 58_AVEAA_4_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_1st/a-58_AVEAA_4_1st_OSI/a-58_AVEAA_4_1st_FTandBBF/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "a-58_AVEAA_4_1st_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)

# %%
## 58_AVEAA_4_12th cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_12th/a-58_AVEAA_4_12th_OSI/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "a-58_AVEAA_4_12th_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)

# %%
## 151_CDGR_11_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_1st/b-151_CDGR_11_1st_OSI/b-151_CDGR_11_1st_FTandBBF/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "b-151_CDGR_11_1st_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)

# %%
## 151_CDGR_11_12th cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_12th/b-151_CDGR_11_12th_OSI/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "b-151_CDGR_11_12th_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)

# %%
## 151_AVEAA_4_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_AVEAA_4_1st/b-151_AVEAA_4_1st_OSI/b-151_AVEAA_4_1st_FTandBBF/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "b-151_AVEAA_4_1st_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)

# %%
## 151_AVEAA_4_12th cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_AVEAA_4_12th/b-151_AVEAA_4_12th_OSI/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "b-151_AVEAA_4_12th_No55")
os.makedirs(new_directory, exist_ok=True)

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(filepath)

        # Convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

        # Check if the 'Time' column exists
        if 'Time' in df.columns:
            # Delete the first and last five minutes of data
            five_minutes = pd.Timedelta(minutes=5)
            min_time = df['Time'].min() + five_minutes
            max_time = df['Time'].max() - five_minutes
            df = df[(df['Time'] > min_time) & (df['Time'] < max_time)]

            # Save the modified DataFrame to a new CSV file in the new directory
            new_filepath = os.path.join(new_directory, filename)
            df.to_csv(new_filepath, index=False)
